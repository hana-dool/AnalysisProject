# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/AnalysisProject
# Out:
# /content/drive/MyDrive/AnalysisProject

# %%
# empty Git repository를 생성합니다. 
# .git 폴더가 생기고, 그 하위에는 여러 폴더가 생긴것을 볼 수 있습니다. 
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/AnalysisProject/.git/

# %%
# %%writefile README.md
# # 샘플입니다.
# - 샘플
# Out:
# Overwriting README.md

# %%
# !git add README.md

# %%
# !git branch -M main
# Out:
# error: refname refs/heads/master not found
# fatal: Branch rename failed

# %%
# !git config --global user.email 'gorany131@gmail.com'
# !git config --global user.name 'hana-dool'

# %%
# !git commit -m "first commit"
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git remote add origin https://hana-dool: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@github.com/hana-dool/AnalysisProject.git

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any.
# error: failed to push some refs to 'https://hana-dool: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@github.com/hana-dool/AnalysisProject.git'
